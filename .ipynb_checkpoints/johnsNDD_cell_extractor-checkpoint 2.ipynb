# %%
### Prerna Singh (edited by John D'Uva)

# Isolate cell regions and non-cell regions (using centers of mass) for 3D sliced Clarity images
# Use a brain-wide illumination correction for intensity
# Extract 10x the non-cell data than cell data by selecting points within 20 pixels x y and z of cells

# %%
import numpy as np
import os
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import random
import csv
import pandas as pd
import cv2

from cloudvolume import CloudVolume, view
from tifffile import imsave
from brainlit.utils.session import NeuroglancerSession
import pickle as pkl
import time
import deflate
# Out:
# /Users/johnduva/opt/anaconda3/envs/neuroData3_7/lib/python3.7/site-packages/python_jsonschema_objects/__init__.py:53: UserWarning: Schema version http://json-schema.org/draft-04/schema not recognized. Some keywords and features may not be supported.
#   self.schema["$schema"]

# %%
# arr = np.empty([33792, 25600, len(os.listdir('pickles'))])
# test = np.load('pickles/image'+str(0)+".pkl", allow_pickle=True)
# test = np.squeeze(test)
# test = np.asarray(test)

# %%
# OPTION 2
dir = "s3://open-neurodata/brainlit/brain1"
vol = CloudVolume(dir, parallel=True, fill_missing=True, cache=True)
begin = 6007
end = 6250

for z in range(begin, end):
    if z % vol.chunk_size.z == 0:
        vol.cache.flush()
    image = vol[:, :, z]
    pkl.dump(image, open("../../../../pickles4/image"+str(z)+".pkl", "wb"))
# Out:
# Downloading: 6972it [00:12, 563.31it/s][00:13<00:53, 60.85it/s]s]
# Downloading: 7992it [00:33, 241.69it/s] [00:30<01:00, 44.26it/s]
# Downloading: 8190it [00:50, 163.40it/s] [00:50<00:09, 67.81it/s]
# Downloading: 8040it [01:00, 132.93it/s] [00:59<00:13, 64.94it/s]
# Downloading: 8160it [01:01, 131.94it/s] [01:02<00:11, 55.08it/s]
# Downloading: 8174it [01:11, 114.78it/s] [01:09<00:08, 55.92it/s]
# Downloading: 8106it [01:10, 115.78it/s]
# Downloading: 8174it [01:11, 114.50it/s]
# Downloading: 8170it [01:12, 112.54it/s]
# Downloading: 8184it [01:11, 114.05it/s]
# Downloading: 8184it [01:12, 112.83it/s]
# Downloading: 8186it [01:14, 110.21it/s]
# Downloading: 8172it [01:17, 104.93it/s]                         ]
# Downloading: 8170it [01:13, 110.78it/s]
# Downloading: 8184it [01:16, 107.34it/s]
# Downloading: 8180it [01:16, 106.93it/s]
# Downloading: 7022it [00:09, 769.00it/s][00:13<01:22, 42.59it/s]]]
# Downloading: 7490it [00:35, 210.88it/s] [00:30<00:57, 42.74it/s]
# Downloading: 8136it [00:48, 168.59it/s] [00:48<00:18, 65.56it/s]
# Downloading: 8170it [01:02, 130.67it/s]
# Downloading: 8016it [01:04, 125.00it/s] [01:07<00:13, 62.62it/s]
# Downloading: 8020it [01:06, 121.22it/s] [01:04<00:09, 69.68it/s]
# Downloading: 8170it [01:07, 120.80it/s]
# Downloading: 8172it [01:14, 110.15it/s]
# Downloading: 8172it [01:14, 109.53it/s]                         ]
# Downloading: 8180it [01:20, 101.81it/s]
# Downloading: 8172it [01:22, 98.69it/s]
# Downloading: 8180it [01:21, 100.08it/s]
# Downloading: 8182it [01:21, 100.04it/s]
# Downloading: 8190it [16:02,  8.51it/s]
# Downloading: 8188it [16:59,  8.03it/s]6 [16:59<00:51,  5.87it/s]
# Downloading: 8190it [17:19,  7.88it/s]
# Downloading: 8190it [17:46,  7.68it/s]
# Downloading: 8188it [17:57,  7.60it/s]
# Downloading: 8186it [18:02,  7.56it/s]
# Downloading: 8188it [18:08,  7.53it/s]
# Downloading: 8188it [18:08,  7.52it/s]
# Downloading: 8188it [18:11,  7.50it/s]
# Downloading: 8174it [18:11,  7.49it/s]
# Downloading: 16380it [03:16, 83.55it/s]                         ]
# Downloading: 16376it [03:19, 82.25it/s]                         ]
# Downloading: 16374it [23:16, 11.73it/s]
# Downloading: 16378it [23:40, 11.53it/s]
# Downloading: 16368it [24:50, 10.98it/s]
# Downloading: 16378it [25:33, 10.68it/s]
# Downloading: 16380it [33:07,  8.24it/s]
# Downloading: 16380it [33:32,  8.14it/s]
# Downloading: 16382it [34:19,  7.95it/s]
# Downloading: 16376it [34:38,  7.88it/s]
# Downloading: 16382it [35:26,  7.70it/s]
# Downloading: 16378it [35:39,  7.65it/s]
# Downloading: 16380it [35:42,  7.64it/s]
# Downloading: 16382it [35:49,  7.62it/s]
# Downloading: 16376it [35:49,  7.62it/s]
# Downloading: 16370it [35:50,  7.61it/s]
# Downloading: 8186it [01:09, 117.27it/s][01:09<26:05,  2.47it/s]
# Downloading: 8176it [03:08, 43.33it/s]
# Downloading: 8184it [09:59, 13.66it/s]
# Downloading: 8188it [10:25, 13.10it/s]
# Downloading: 8178it [13:54,  9.80it/s]
# Downloading: 8190it [14:42,  9.28it/s]
# Downloading:  85%|████████▌ | 3493/4096 [15:18<02:15,  4.47it/s]

# %%
# create np array from cloudvolume?
arr = np.empty([33792, 25600, len(os.listdir('pickles4'))])
# load pickle data
for i in range(0, len(os.listdir('pickles'))):
    arr[:,:,i] = np.load('"../../../../pickles4/image'+str(i)+".pkl", allow_pickle=True)

# %%
import numpy as np
import os
i = 1
# arr = np.empty([33792, 25600, len(os.listdir('../../../../pickles2'))])
arr = np.empty([33792, 25600, 1])
test = np.load('../../../../pickles2/image'+str(100)+".pkl", allow_pickle=True)
test2 = np.squeeze(test)
arr[:,:,0] = test2
# # os.listdir('../../../../')
# Out:
# (33792, 25600)

# %%
import matplotlib as plt
from PIL import Image
img2 = arr[:,:,0]
img = Image.fromarray(img2, 'RGB')
img.show()

# %%
# save each of 'i' z-planes locally (from the tiff stack)
for i in range(0,image.shape[2]):
    if i <10:
        name = "brian-dev_"+date+"_ENTAGLaGP-"+section+"_Ch0_470_z0-2160_y0-2560_z000%i" %i
    elif i <100:
        name = "brian-dev_"+date+"_ENTAGLaGP-"+section+"_Ch0_470_z0-2160_y0-2560_z00%i" %i
    elif i <1000:
        name = "brian-dev_"+date+"_ENTAGLaGP-"+section+"_Ch0_470_z0-2160_y0-2560_z0%i" %i
    else:
        name = "brian-dev_"+date+"_ENTAGLaGP-"+section+"_Ch0_470_z0-2160_y0-2560_z%i" %i
    imsave(section+"/%s.tiff" %name, image[:,:,i])

# %%
# nd.arrayimage
np.array(image)
# image[:,:,0].show()

# %%
# create directory
file_path_img = os.path.join(section)
list = os.listdir(file_path_img)

# %%
#preprocess the csv with file labels
fileLabelCSV = pd.read_csv('/Users/johnduva/Desktop/2020/csvs/E'+section+'-training.csv')

#make ordered lists of each coordinate dimension
xfileLabelCSV=(fileLabelCSV['Center of Mass (Geometry): X (px)']).to_list()
yfileLabelCSV=(fileLabelCSV['Center of Mass (Geometry): Y (px)']).to_list()
zfileLabelCSV=(fileLabelCSV['Center of Mass (Geometry): Z (px)']).to_list()
      
ROI = np.zeros((len(xfileLabelCSV),12,12,12))

#create a list of ranges +-6 from the cell coordinate that are invalid when accumulating non-cell regions
x_invalid=[]
y_invalid=[]
z_invalid=[]
for index0 in range(0,len(xfileLabelCSV)):
    voxel = np.zeros((12,12,12))
    #current coordinates
    xcoord = int(xfileLabelCSV[index0])
    ycoord = int(yfileLabelCSV[index0])
    zcoord = int(zfileLabelCSV[index0])
    
    #for the ncrs
    x_invalid+=[*range(int(xfileLabelCSV[index0])-6,int(xfileLabelCSV[index0])+6)]
    y_invalid+=[*range(int(yfileLabelCSV[index0])-6,int(yfileLabelCSV[index0])+6)]
    z_invalid+=[*range(int(zfileLabelCSV[index0])-6,int(zfileLabelCSV[index0])+6)]
    
    
    #for every z, append the x&ys
    for index, i in enumerate(range(zcoord-6,zcoord+6)):
        for file in list:
            if str("tif") in str(file):
                if len(str(i))==1:
                    i=str("000"+str(i))
                if len(str(i))==2:
                    i=str("00"+str(i))
                if len(str(i))==3:
                    i=str("0"+str(i))
                if str(i) in str(file).split("_")[7]:
                    scan1 = np.asarray(Image.open(file_path_img + '/'+file))
                    scan = np.zeros(scan1.shape)
                    scan = cv2.normalize(scan1,scan, 0, 255, cv2.NORM_MINMAX)
                    plane = scan[xcoord-6:xcoord+6,ycoord-6:ycoord+6]
                    #plt.imshow(plane)
                    #plt.show()
        voxel[index]=np.asarray(plane)
    ROI[index0]=np.asarray(voxel)

print('Total number of CellRegions: ', len(zfileLabelCSV))

# %%
np.save('ROI'+section+'_bias_corrected.npy', ROI)

# %%
#export cell coordinates as .npy
xcoordinate=(fileLabelCSV['Center of Mass (Geometry): X (px)']).to_numpy()
ycoordinate=(fileLabelCSV['Center of Mass (Geometry): Y (px)']).to_numpy()
zcoordinate=(fileLabelCSV['Center of Mass (Geometry): Z (px)']).to_numpy()

# %%
#number of non-coding regions we want to isolate, lets say 515, same as number of cell regions
nNCMB = len(zfileLabelCSV)*10
NCR = []

#have 11 different coordinates for 1 non-cell region
for index0 in range(0,len(xfileLabelCSV)):
    #current coordinates
    xcoord = int(xfileLabelCSV[index0])
    ycoord = int(yfileLabelCSV[index0])
    zcoord = int(zfileLabelCSV[index0])
    ncrcell=[]
    while (len(ncrcell)) < 10:
        x_random = random.randint(7,20)
        y_random = random.randint(7,20)
        z_random = random.randint(7,20)
        #proceed =1
        #print("Random x,y,z for Non CMB Region:", x_random,y_random,z_random)

        #for i in x_invalid:
        #    if x_random == i:
        #        #print('x_false')
        #        proceed = 0
        #for i in y_invalid:
        #    if y_random == i:
        #        #print('y_false')
        #        proceed = 0
        #for i in z_invalid:
        #    if z_random == i:
        #        #print('z_false')
        #        proceed = 0
        if len(ncrcell) %8==0:
            #print("proceeding")
            ncrcell.append([xcoord+x_random,ycoord+y_random,zcoord+z_random])
        elif len(ncrcell) %8==1:
            #print("proceeding")
            ncrcell.append([xcoord-x_random,ycoord+y_random,zcoord+z_random])
        elif len(ncrcell) %8==2:
            #print("proceeding")
            ncrcell.append([xcoord+x_random,ycoord-y_random,zcoord+z_random])
        elif len(ncrcell) %8==3:
            #print("proceeding")
            ncrcell.append([xcoord+x_random,ycoord+y_random,zcoord-z_random])
        elif len(ncrcell) %8==4:
            #print("proceeding")
            ncrcell.append([xcoord+x_random,ycoord-y_random,zcoord-z_random])
        elif len(ncrcell) %8==5:
            #print("proceeding")
            ncrcell.append([xcoord-x_random,ycoord+y_random,zcoord-z_random])
        elif len(ncrcell) %8==6:
            #print("proceeding")
            ncrcell.append([xcoord-x_random,ycoord-y_random,zcoord+z_random])
        else:
            ncrcell.append([xcoord-x_random,ycoord-y_random,zcoord-z_random])
    for i in ncrcell:
        NCR.append(i)
    #print(len(NCR))
print("%s non-CMB regions were isolated." %(len(NCR)), "Adding to the master dictionary.")

# %%
NCR_total = np.zeros((len(NCR),12,12,12))

for index0 in range(0,len(NCR)):
    voxel = np.zeros((12,12,12))
    
    #current coordinates
    xcoord = int(NCR[index0][0])
    ycoord = int(NCR[index0][1])
    zcoord = int(NCR[index0][2])

    #for every z, append the x&ys
    for index,i in enumerate(range(zcoord-6,zcoord+6)):
        for file in list:
            if str("tif") in str(file):
                if len(str(i))==1:
                    i=str("000"+str(i))
                if len(str(i))==2:
                    i=str("00"+str(i))
                if len(str(i))==3:
                    i=str("0"+str(i))
                if str(i) in str(file).split("_")[7]:
                    scan1 = np.asarray(Image.open(file_path_img + '/'+file))
                    scan = np.zeros(scan1.shape)
                    scan = cv2.normalize(scan1,scan, 0, 255, cv2.NORM_MINMAX)
                    plane = scan[xcoord-6:xcoord+6,ycoord-6:ycoord+6]
        voxel[index] = np.asarray(plane)
    NCR_total[index0]=np.asarray(voxel)

# %%
np.save('NCR'+section+'_bias_corrected.npy',np.asarray(NCR_total))

# %%
NCR[2]

# %%
image.shape[2]

# %%
plt.imshow(scan[NCR[34][0]-30:NCR[34][0]+30,NCR[34][1]-30:NCR[34][1]+30])
plt.show()

# %%
plt.imshow(NCR_total[34][5])

# %%
# OPTION 1
# dir = "s3://open-neurodata/brainlit/brain1"
# vol = CloudVolume(dir, parallel=True, fill_missing=True)

# begin = vol.voxel_offset.z # 0
# end = vol.shape[2]         # 13,312
# chunk = vol.chunk_size.z   # 52

# for z in range(vol.voxel_offset.z, vol.voxel_offset.z + vol.shape[2] + 1, vol.chunk_size.z):
#     image = vol[:, :, z : z+chunk-1]
#     print("z #"+str(z))
#     for j in range(chunk):
#         image_slice = image[:,:,j]
#         pkl.dump(image_slice, open("pickles3/image"+str(z)+"_"+str(j)+".pkl", "wb"))
#         print("j #"+str(j))
